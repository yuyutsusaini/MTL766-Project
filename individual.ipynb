# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import stats as st
#
# ModuleNotFoundError: No module named 'stats'

# %%
df = pd.read_csv('Customer Purchasing Behaviors.csv')
grouped = df.groupby('region')

# %%
for region, group_data in grouped:
    print(f"Correlation Matrix for Region: {region}")
    
    # Select only numeric columns
    numeric_data = group_data.select_dtypes(include='number')
    
    # Calculate the correlation matrix
    correlation_matrix = numeric_data.corr()
    
    # Step 3: Plot the correlation matrix as a heatmap
    # print the correlation matrix side by side
    plt.figure(figsize=(4, 3))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f"Correlation Matrix for Region: {region}")
    plt.show()
# Out:
# Correlation Matrix for Region: East
# Correlation Matrix for Region: North
# Correlation Matrix for Region: South
# Correlation Matrix for Region: West

# %%
# Age vs Income for each region
for region, group_data in grouped:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=group_data, x='age', y='annual_income')
    plt.title(f"Age vs Income for Region: {region}")
    plt.show()

# %%
print(df.describe())
# Out:
#           user_id         age  annual_income  purchase_amount  loyalty_score  \
# count  238.000000  238.000000     238.000000       238.000000     238.000000
# mean   119.500000   38.676471   57407.563025       425.630252       6.794118
# std     68.848868    9.351118   11403.875717       140.052062       1.899047
# min      1.000000   22.000000   30000.000000       150.000000       3.000000
# 25%     60.250000   31.000000   50000.000000       320.000000       5.500000
# 50%    119.500000   39.000000   59000.000000       440.000000       7.000000
# 75%    178.750000   46.750000   66750.000000       527.500000       8.275000
# max    238.000000   55.000000   75000.000000       640.000000       9.500000
#
#        purchase_frequency
# count          238.000000
# mean            19.798319
# std              4.562884
# min             10.000000
# 25%             17.000000
# 50%             20.000000
# 75%             23.000000
# max             28.000000

# %%
# group the data by nort east and south west
df=df.drop(columns=['user_id','loyalty_score'])
grouped = df.groupby('region')
# combine north with east and south with west
grouped = df.groupby(df['region'].map(lambda x: 'North-East' if x in ['North', 'East'] else 'South-West'))
for region, group_data in grouped:
    print(f"Correlation Matrix for Region: {region}")
    
    # Select only numeric columns
    numeric_data = group_data.select_dtypes(include='number')
    
    # Calculate the correlation matrix
    correlation_matrix = numeric_data.corr()
    
    # Step 3: Plot the correlation matrix as a heatmap
    # print the correlation matrix side by side
    plt.figure(figsize=(4, 3))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f"Correlation Matrix for Region: {region}")
    plt.show()
# Out:
# Correlation Matrix for Region: North-East
# Correlation Matrix for Region: South-West

# %%
print(type(grouped))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
# Distribution of Numeric Features
plt.figure(figsize=(10, 6))
# remove user id column from the histogram
# dont frop from dataframe
grouped.hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# Draw Q-Q plot for each region
for region, group_data in grouped:
    plt.figure(figsize=(8, 6))
    for column in group_data.select_dtypes(include='number'):
        # Create a Q-Q plot
        stats.probplot(group_data[column], dist="norm", plot=plt)
        plt.title(f"Q-Q plot for {column} in Region: {region}")
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb Cell 9 line 6
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(8, 6))
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> for column in group_data.select_dtypes(include='number'):
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     # Create a Q-Q plot
# ----> <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     stats.probplot(group_data[column], dist="norm", plot=plt)
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>     plt.title(f"Q-Q plot for {column} in Region: {region}")
#       <a href='vscode-notebook-cell:/Users/yuyutsusaini/saini/Semester/Sem9/MTL766/individual.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     plt.show()
#
# NameError: name 'stats' is not defined
