# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
df = pd.read_csv('Customer Purchasing Behaviors.csv')

# %%
# List of columns for which you want to check the Q-Q plot
# columns_to_check = ['age', 'annual_income', 'purchase_amount']

# Loop through each numeric column and create Q-Q plots

# # for column in columns_to_check:
# for column in df.drop(columns=['user_id','region']).columns:
#     # Q-Q plot using scipy
#     stats.probplot(df[column], dist="norm", plot=plt)
    
#     # Add title and labels
#     plt.title(f"Q-Q Plot for {column}")
#     plt.xlabel("Theoretical Quantiles")
#     plt.ylabel("Sample Quantiles")
    
#     plt.show()

# plot the Q-Q plot side by side with other Q-Q plots
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))
fig, axs = plt.subplots(5, 1, figsize=(8, 22))

for i, column in enumerate(df.drop(columns=['user_id','region']).columns):
    stats.probplot(df[column], dist="norm", plot=axs[i])
    axs[i].set_title(f"Q-Q Plot for {column}")
    axs[i].set_xlabel("Theoretical Quantiles")
    axs[i].set_ylabel("Sample Quantiles")

plt.tight_layout()
plt.show()
